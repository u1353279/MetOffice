# %% [markdown]
# <a href="https://colab.research.google.com/github/u1353279/MetOffice/blob/main/Auto_ts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Little Rissington***
#
#
#
# Data Analysis

# %%
import pandas as pd
import numpy as np

# stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# plotting
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)

# %%
# %matplotlib inline
plt.style.use('seaborn-darkgrid')
from matplotlib import rcParams
rcParams['font.family'] = 'monospace'
rcParams['font.sans-serif'] = ['Lucida Console']

# %%
df=pd.read_excel('/content/drive/MyDrive/PHD/little_rissington.xlsx')

# %%
df
# Out:
#             Date  ...  Daily Total Global Radiation (KJ/m2)
# 0     01/01/2010  ...                                5425.0
# 1     02/01/2010  ...                                4761.0
# 2     03/01/2010  ...                                5416.0
# 3     04/01/2010  ...                                6301.0
# 4     05/01/2010  ...                                2318.0
# ...          ...  ...                                   ...
# 3647  27/12/2019  ...                                1348.0
# 3648  28/12/2019  ...                                1285.0
# 3649  29/12/2019  ...                                1651.0
# 3650  30/12/2019  ...                                3075.0
# 3651  31/12/2019  ...                                 689.0
#
# [3652 rows x 8 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

# %%
df.rename(columns={'Daily Maximum Temperature (0900-0900) (°C)': 'Max Temp',
                   'Daily Minimum Temperature (0900-0900) (°C)': 'Min Temp',
                  'Daily Mean Temperature (0900-0900) (°C)': 'Mean Temp',
          'Daily Total Rainfall (0900-0900)(mm)': 'Rainfall(mm)',
          'Daily Mean Windspeed (0100-2400) (kn)': 'Windspeed(kn)',
          'Daily Maximum Gust (0100-2400) (kn)': 'Max Gust(kn)',
          'Daily Total Global Radiation (KJ/m2)': 'Radiation(KJ/m2)'},
          inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                 0
# Max Temp            17
# Min Temp            17
# Mean Temp           21
# Rainfall(mm)         0
# Windspeed(kn)       31
# Max Gust(kn)        31
# Radiation(KJ/m2)    34
# dtype: int64

# %%
# only show the missing values
df[df.filter(like='Max Temp').isnull().any(1)]
# Out:
#            Date  Max Temp  ...  Max Gust(kn)  Radiation(KJ/m2)
# 2478 2016-10-14       NaN  ...           NaN               NaN
# 2479 2016-10-15       NaN  ...           NaN               NaN
# 2480 2016-10-16       NaN  ...           NaN               NaN
# 2481 2016-10-17       NaN  ...           NaN               NaN
# 2482 2016-10-18       NaN  ...           NaN               NaN
# 2483 2016-10-19       NaN  ...           NaN               NaN
# 3500 2019-08-02       NaN  ...           NaN               NaN
# 3501 2019-08-03       NaN  ...           NaN               NaN
# 3502 2019-08-04       NaN  ...           NaN               NaN
# 3503 2019-08-05       NaN  ...           NaN               NaN
# 3504 2019-08-06       NaN  ...           NaN               NaN
# 3522 2019-08-24       NaN  ...           NaN               NaN
# 3523 2019-08-25       NaN  ...           NaN               NaN
# 3524 2019-08-26       NaN  ...           NaN               NaN
# 3525 2019-08-27       NaN  ...           NaN               NaN
# 3536 2019-09-07       NaN  ...          20.0               NaN
# 3537 2019-09-08       NaN  ...           NaN               NaN
#
# [17 rows x 8 columns]

# %%
#propogate the last valid observation forward
df.ffill()
# Out:
#            Date  Max Temp  ...  Max Gust(kn)  Radiation(KJ/m2)
# 0    2010-01-01       0.3  ...          19.0            5425.0
# 1    2010-01-02       3.9  ...          18.0            4761.0
# 2    2010-01-03       0.9  ...          19.0            5416.0
# 3    2010-01-04       0.2  ...          10.0            6301.0
# 4    2010-01-05      -0.1  ...          15.0            2318.0
# ...         ...       ...  ...           ...               ...
# 3647 2019-12-27       7.5  ...          15.0            1348.0
# 3648 2019-12-28       8.5  ...          20.0            1285.0
# 3649 2019-12-29       6.9  ...          23.0            1651.0
# 3650 2019-12-30       7.6  ...          20.0            3075.0
# 3651 2019-12-31       7.0  ...          18.0             689.0
#
# [3652 rows x 8 columns]

# %%
df.ffill(inplace=True)

# %%
df['month'] = df['Date'].dt.month

# %%
df['year'] = df['Date'].dt.year

# %%
df1=df[['Date','Radiation(KJ/m2)']]

# %%
df1
# Out:
#            Date  Radiation(KJ/m2)
# 0    2010-01-01            5425.0
# 1    2010-01-02            4761.0
# 2    2010-01-03            5416.0
# 3    2010-01-04            6301.0
# 4    2010-01-05            2318.0
# ...         ...               ...
# 3647 2019-12-27            1348.0
# 3648 2019-12-28            1285.0
# 3649 2019-12-29            1651.0
# 3650 2019-12-30            3075.0
# 3651 2019-12-31             689.0
#
# [3652 rows x 2 columns]

# %%
train_df = df1.iloc[:, :3000]
test_df = df1.iloc[3000:, :]

# %%
train_df
# Out:
#            Date  Radiation(KJ/m2)
# 0    2010-01-01            5425.0
# 1    2010-01-02            4761.0
# 2    2010-01-03            5416.0
# 3    2010-01-04            6301.0
# 4    2010-01-05            2318.0
# ...         ...               ...
# 3647 2019-12-27            1348.0
# 3648 2019-12-28            1285.0
# 3649 2019-12-29            1651.0
# 3650 2019-12-30            3075.0
# 3651 2019-12-31             689.0
#
# [3652 rows x 2 columns]

# %%
test_df
# Out:
#            Date  Radiation(KJ/m2)
# 3000 2018-03-20            9288.0
# 3001 2018-03-21           15722.0
# 3002 2018-03-22            7285.0
# 3003 2018-03-23            8673.0
# 3004 2018-03-24            5310.0
# ...         ...               ...
# 3647 2019-12-27            1348.0
# 3648 2019-12-28            1285.0
# 3649 2019-12-29            1651.0
# 3650 2019-12-30            3075.0
# 3651 2019-12-31             689.0
#
# [652 rows x 2 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              3652 non-null   datetime64[ns]
#  1   Radiation(KJ/m2)  3652 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 57.2 KB

# %%
train_df.set_index("Date", inplace=True)
test_df.set_index("Date", inplace=True)

# %%
train_df.head()
# Out:
#             Radiation(KJ/m2)
# Date
# 2010-01-01            5425.0
# 2010-01-02            4761.0
# 2010-01-03            5416.0
# 2010-01-04            6301.0
# 2010-01-05            2318.0

# %%
train_df['Radiation(KJ/m2)'].plot(figsize=(15,8), title= 'Radiation', fontsize=14)
test_df['Radiation(KJ/m2)'].plot(figsize=(15,8), title= 'Radiation', fontsize=14)
plt.show()

# %%
# !pip install auto_ts --ignore-installed --no-cache-dir
# Out:
# Collecting auto_ts
#   Downloading https://files.pythonhosted.org/packages/64/09/8687969f457648a1410dff562bd72d74ed48c06a93ccddff28259e53f8fc/auto_ts-0.0.32-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 6.9MB/s
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/30/aa/db462d385c56905b731403885454188683f63c86ea68900f6f7e7558b5fa/scikit_learn-0.24.0-cp36-cp36m-manylinux2010_x86_64.whl (22.2MB)
#      |████████████████████████████████| 22.2MB 1.3MB/s
# Collecting xgboost
#   Downloading https://files.pythonhosted.org/packages/29/c8/d6ff9fe39cb93ef2e66bb411c69e0135dd1b1ea98827eadbb2ba8baecb44/xgboost-1.3.1-py3-none-manylinux2010_x86_64.whl (157.5MB)
#      |████████████████████████████████| 157.5MB 1.2MB/s
# Collecting ipython
#   Downloading https://files.pythonhosted.org/packages/23/6a/210816c943c9aeeb29e4e18a298f14bf0e118fe222a23e13bfcc2d41b0a4/ipython-7.16.1-py3-none-any.whl (785kB)
#      |████████████████████████████████| 788kB 53.2MB/s
# Collecting statsmodels
#   Downloading https://files.pythonhosted.org/packages/be/4c/9e2435ca6645d6bafa2b51bb11f0a365b28934a2ffe9d6e339d67130926d/statsmodels-0.12.1-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 50.4MB/s
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/d2/43/2bd63467490036697e7be71444fafc7b236923d614d4521979a200c6b559/matplotlib-3.3.3-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#      |████████████████████████████████| 11.6MB 48.3MB/s
# Collecting prettytable
#   Downloading https://files.pythonhosted.org/packages/94/d5/52e48f3bcf66f838d411ad85c3ac9550c2451d082623e2d4d4df7411ed5c/prettytable-2.0.0-py3-none-any.whl
# Collecting seaborn
#   Downloading https://files.pythonhosted.org/packages/68/ad/6c2406ae175f59ec616714e408979b674fe27b9587f79d59a528ddfbcd5b/seaborn-0.11.1-py3-none-any.whl (285kB)
#      |████████████████████████████████| 286kB 46.0MB/s
# Collecting jupyter
#   Downloading https://files.pythonhosted.org/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/c3/e2/00cacecafbab071c787019f00ad84ca3185952f6bb9bca9550ed83870d4d/pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 45.4MB/s
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/c9/d7/61af1897449638822f97c8b43ef0c2fce2ec68a6cda9a43ebbbdd12b967c/pmdarima-1.8.0-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 52.5MB/s
# Collecting fbprophet
#   Downloading https://files.pythonhosted.org/packages/1a/b5/9c3fefa8a7b839729df57deedf0a69815841dfb88f0df911f34d998230b7/fbprophet-0.7.1.tar.gz (64kB)
#      |████████████████████████████████| 71kB 57.9MB/s
# Collecting scipy>=0.19.1
#   Downloading https://files.pythonhosted.org/packages/c8/89/63171228d5ced148f5ced50305c89e8576ffc695a90b58fe5bb602b910c2/scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
#      |████████████████████████████████| 25.9MB 1.2MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Collecting numpy>=1.13.3
#   Downloading https://files.pythonhosted.org/packages/14/32/d3fa649ad7ec0b82737b92fefd3c4dd376b0bb23730715124569f38f3a08/numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 49.8MB/s
# Collecting joblib>=0.11
#   Downloading https://files.pythonhosted.org/packages/34/5b/bd0f0fb5564183884d8e35b81d06d7ec06a20d1a0c8b4c407f1554691dce/joblib-1.0.0-py3-none-any.whl (302kB)
#      |████████████████████████████████| 307kB 63.1MB/s
# Collecting pickleshare
#   Downloading https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting jedi>=0.10
#   Downloading https://files.pythonhosted.org/packages/f9/36/7aa67ae2663025b49e8426ead0bad983fee1b73f472536e9790655da0277/jedi-0.18.0-py2.py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 49.0MB/s
# Collecting setuptools>=18.5
#   Downloading https://files.pythonhosted.org/packages/aa/d4/0089d680a610c7b5afda26c1ae588eb363b9050ccf5f33a8c2d1164210f3/setuptools-51.1.2-py3-none-any.whl (784kB)
#      |████████████████████████████████| 788kB 45.3MB/s
# Collecting decorator
#   Downloading https://files.pythonhosted.org/packages/ed/1b/72a1821152d07cf1d8b6fce298aeb06a7eb90f4d6d41acec9861e7cc6df0/decorator-4.4.2-py2.py3-none-any.whl
# Collecting pygments
#   Downloading https://files.pythonhosted.org/packages/17/e3/c7ea888bd6e9849c60b1f378637850265177ed01297137f544a7ecf7d7ba/Pygments-2.7.4-py3-none-any.whl (950kB)
#      |████████████████████████████████| 952kB 59.9MB/s
# Collecting pexpect; sys_platform != "win32"
#   Downloading https://files.pythonhosted.org/packages/39/7b/88dbb785881c28a102619d46423cb853b46dbccc70d3ac362d99773a78ce/pexpect-4.8.0-py2.py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 49.6MB/s
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/9f/48/a1a6177a3b5c31b44bf9d5af7a9a87bba2b0adcba85b8b91450c66a6abf9/prompt_toolkit-3.0.10-py3-none-any.whl (355kB)
#      |████████████████████████████████| 358kB 63.2MB/s
# Collecting backcall
#   Downloading https://files.pythonhosted.org/packages/4c/1c/ff6546b6c12603d8dd1070aa3c3d273ad4c07f5771689a7b69a550e8c951/backcall-0.2.0-py2.py3-none-any.whl
# Collecting traitlets>=4.2
#   Downloading https://files.pythonhosted.org/packages/ca/ab/872a23e29cec3cf2594af7e857f18b687ad21039c1f9b922fac5b9b142d5/traitlets-4.3.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 69.7MB/s
# Collecting patsy>=0.5
#   Downloading https://files.pythonhosted.org/packages/ea/0c/5f61f1a3d4385d6bf83b83ea495068857ff8dfb89e74824c6e9eb63286d8/patsy-0.5.1-py2.py3-none-any.whl (231kB)
#      |████████████████████████████████| 235kB 61.2MB/s
# Collecting cycler>=0.10
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting pillow>=6.2.0
#   Downloading https://files.pythonhosted.org/packages/b6/c0/442d9d87e0da00bf856ef6dd4916f84a2d710b5f1a367d42d7f3c4e99a6c/Pillow-8.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 52.2MB/s
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading https://files.pythonhosted.org/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 55.3MB/s
# Collecting python-dateutil>=2.1
#   Downloading https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl (227kB)
#      |████████████████████████████████| 235kB 59.5MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/a7/1b/cbd8ae738719b5f41592a12057ef5442e2ed5f5cb5451f8fc7e9f8875a1a/kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 46.6MB/s
# Collecting wcwidth
#   Downloading https://files.pythonhosted.org/packages/59/7c/e39aca596badaf1b78e8f547c807b04dae603a433d3e7a7e04d67f2ef3e5/wcwidth-0.2.5-py2.py3-none-any.whl
# Collecting ipykernel
#   Downloading https://files.pythonhosted.org/packages/7d/cc/e8908bbb2921732f6851ebbbe4b77b925aab62e644ab9402f21c84fa6107/ipykernel-5.4.3-py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 44.8MB/s
# Collecting notebook
#   Downloading https://files.pythonhosted.org/packages/89/8f/0ece1a79baf28514527b21426727472718a9631a2a5ca6840bdbcbd44f41/notebook-6.1.6-py3-none-any.whl (9.5MB)
#      |████████████████████████████████| 9.5MB 51.5MB/s
# Collecting nbconvert
#   Downloading https://files.pythonhosted.org/packages/13/2f/acbe7006548f3914456ee47f97a2033b1b2f3daf921b12ac94105d87c163/nbconvert-6.0.7-py3-none-any.whl (552kB)
#      |████████████████████████████████| 552kB 44.9MB/s
# Collecting jupyter-console
#   Downloading https://files.pythonhosted.org/packages/65/de/8f9491c4b7e660a75a4eb54694292d918d2d29321936d26bad28cc0530a4/jupyter_console-6.2.0-py3-none-any.whl
# Collecting ipywidgets
#   Downloading https://files.pythonhosted.org/packages/11/53/084940a83a8158364e630a664a30b03068c25ab75243224d6b488800d43a/ipywidgets-7.6.3-py2.py3-none-any.whl (121kB)
#      |████████████████████████████████| 122kB 54.1MB/s
# Collecting qtconsole
#   Downloading https://files.pythonhosted.org/packages/ab/a0/039a8f9c733ff48f1ab2f14d5e1a3bb9d34e038b40b82650ba8d7c5778e0/qtconsole-5.0.1-py3-none-any.whl (118kB)
#      |████████████████████████████████| 122kB 54.0MB/s
# Collecting pytz>=2017.2
#   Downloading https://files.pythonhosted.org/packages/89/06/2c2d3034b4d6bf22f2a4ae546d16925898658a33b4400cfb7e2c1e2871a3/pytz-2020.5-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 48.4MB/s
# Collecting urllib3
#   Downloading https://files.pythonhosted.org/packages/f5/71/45d36a8df68f3ebb098d6861b2c017f3d094538c0fb98fa61d4dc43e69b9/urllib3-1.26.2-py2.py3-none-any.whl (136kB)
#      |████████████████████████████████| 143kB 56.7MB/s
# Collecting Cython<0.29.18,>=0.29
#   Downloading https://files.pythonhosted.org/packages/e7/d7/510ddef0248f3e1e91f9cc7e31c0f35f8954d0af92c5c3fd4c853e859ebe/Cython-0.29.17-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 46.2MB/s
# Collecting cmdstanpy==0.9.5
#   Downloading https://files.pythonhosted.org/packages/e3/e2/204c9c6beaf9e05ad28bd589c154afff35dffa6166d76841d3c0dec6c1e3/cmdstanpy-0.9.5-py3-none-any.whl
# Collecting pystan>=2.14
#   Downloading https://files.pythonhosted.org/packages/b9/97/a613a98b72090e36b3bc5edc56977596038986cd224a2ae651c4c6a688b3/pystan-2.19.1.1-cp36-cp36m-manylinux1_x86_64.whl (67.3MB)
#      |████████████████████████████████| 67.3MB 1.2MB/s
# Collecting LunarCalendar>=0.0.9
#   Downloading https://files.pythonhosted.org/packages/ab/e0/a52ffc02395474858552ca6437226e23ad67e25fd85cb387f02e479cfe01/LunarCalendar-0.0.9-py2.py3-none-any.whl
# Collecting convertdate>=2.1.2
#   Downloading https://files.pythonhosted.org/packages/ca/7b/ba752f4383dd775de1fa825d4a3bf1df4109be9a1986c905232c83373615/convertdate-2.3.0-py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 51.3MB/s
# Collecting holidays>=0.10.2
#   Downloading https://files.pythonhosted.org/packages/cc/14/a8a30bae14091984acd262526a258b1890c3ada0e5ae0da747e2b8f2b77d/holidays-0.10.4.tar.gz (120kB)
#      |████████████████████████████████| 122kB 60.9MB/s
# Collecting setuptools-git>=1.2
#   Downloading https://files.pythonhosted.org/packages/05/97/dd99fa9c0d9627a7b3c103a00f1566d8193aca8d473884ed258cca82b06f/setuptools_git-1.2-py2.py3-none-any.whl
# Collecting tqdm>=4.36.1
#   Downloading https://files.pythonhosted.org/packages/80/02/8f8880a4fd6625461833abcf679d4c12a44c76f9925f92bf212bb6cefaad/tqdm-4.56.0-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 55.9MB/s
# Collecting parso<0.9.0,>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/ad/f0/ef6bdb1eba2dbfda60c985cd8d7b47b6ed8c6a1f5d212f39ff50b64f172c/parso-0.8.1-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 57.9MB/s
# Collecting ptyprocess>=0.5
#   Downloading https://files.pythonhosted.org/packages/22/a6/858897256d0deac81a172289110f31629fc4cee19b6f01283303e18c8db3/ptyprocess-0.7.0-py2.py3-none-any.whl
# Collecting six
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting ipython-genutils
#   Downloading https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-client
#   Downloading https://files.pythonhosted.org/packages/83/d6/30aed7ef13ff3f359e99626c1b0a32ebbc3bf9b9d5616ec46e9e245d5fa9/jupyter_client-6.1.11-py3-none-any.whl (108kB)
#      |████████████████████████████████| 112kB 74.7MB/s
# Collecting tornado>=4.2
#   Downloading https://files.pythonhosted.org/packages/85/26/e710295dcb4aac62b08f22d07efc899574476db37532159a7f71713cdaf2/tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427kB)
#      |████████████████████████████████| 430kB 63.4MB/s
# Collecting pyzmq>=17
#   Downloading https://files.pythonhosted.org/packages/05/87/bfed82301b9e9f847f48a14722a61aa1d6249d98e00e6825dd9b7e70abe4/pyzmq-20.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 43.5MB/s
# Collecting prometheus-client
#   Downloading https://files.pythonhosted.org/packages/f4/7e/ef341c67ed43ad2e39633a35c28b77bc555f9572f4df4fee11c2b467db00/prometheus_client-0.9.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 52.3MB/s
# Collecting Send2Trash
#   Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting jinja2
#   Downloading https://files.pythonhosted.org/packages/30/9e/f663a2aa66a09d838042ae1a2c5659828bb9b41ea3a6efa20a20fd92b121/Jinja2-2.11.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 52.9MB/s
# Collecting nbformat
#   Downloading https://files.pythonhosted.org/packages/40/f7/b9a7c82aff85b706f2824c97727b8e2106bb992bd553e93082b9c6dd45fe/nbformat-5.0.8-py3-none-any.whl (172kB)
#      |████████████████████████████████| 174kB 43.9MB/s
# Collecting terminado>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/de/74/604d9dcbb5b73b54d07c78764b22568b8c7923d93e257dc9766142f67b81/terminado-0.9.2-py3-none-any.whl
# Collecting jupyter-core>=4.6.1
#   Downloading https://files.pythonhosted.org/packages/f4/34/ba811d7e4b5374e70fc3801d932966979e252e5c1a99eddb32ce63ec54e6/jupyter_core-4.7.0-py3-none-any.whl (82kB)
#      |████████████████████████████████| 92kB 57.7MB/s
# Collecting argon2-cffi
#   Downloading https://files.pythonhosted.org/packages/e0/d7/5da06217807106ed6d7b4f5ccb8ec5e3f9ec969217faad4b5d1af0b55101/argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97kB)
#      |████████████████████████████████| 102kB 50.9MB/s
# Collecting testpath
#   Downloading https://files.pythonhosted.org/packages/1b/9e/1a170feaa54f22aeb5a5d16c9015e82234275a3c8ab630b552493f9cb8a9/testpath-0.4.4-py2.py3-none-any.whl (163kB)
#      |████████████████████████████████| 174kB 57.0MB/s
# Collecting bleach
#   Downloading https://files.pythonhosted.org/packages/03/c8/b7ed0dfea5cb287907bd22c5ff7c3ed0a65b346f2a4cf916eb9e83be66b3/bleach-3.2.1-py2.py3-none-any.whl (145kB)
#      |████████████████████████████████| 153kB 57.6MB/s
# Collecting mistune<2,>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting pandocfilters>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/28/78/bd59a9adb72fa139b1c9c186e6f65aebee52375a747e4b6a6dcf0880956f/pandocfilters-1.4.3.tar.gz
# Collecting jupyterlab-pygments
#   Downloading https://files.pythonhosted.org/packages/a8/6f/c34288766797193b512c6508f5994b830fb06134fdc4ca8214daba0aa443/jupyterlab_pygments-0.1.2-py2.py3-none-any.whl
# Collecting entrypoints>=0.2.2
#   Downloading https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/fd/4f/5cbd9bdb30bfaad620f028711bf232b9cec8fdff1dcf68d9259254fcddeb/nbclient-0.5.1-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 56.1MB/s
# Collecting defusedxml
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6"
#   Downloading https://files.pythonhosted.org/packages/18/b5/3473d275e3b2359efdf5768e9df95537308b93a31ad94fa92814ac565826/jupyterlab_widgets-1.0.0-py3-none-any.whl (243kB)
#      |████████████████████████████████| 245kB 55.3MB/s
# Collecting widgetsnbextension~=3.5.0
#   Downloading https://files.pythonhosted.org/packages/6c/7b/7ac231c20d2d33c445eaacf8a433f4e22c60677eb9776c7c5262d7ddee2d/widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 39.2MB/s
# Collecting qtpy
#   Downloading https://files.pythonhosted.org/packages/cd/fd/9972948f02e967b691cc0ca1f26124826a3b88cb38f412a8b7935b8c3c72/QtPy-1.9.0-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 47.7MB/s
# Collecting ephem>=3.7.5.3
#   Downloading https://files.pythonhosted.org/packages/6e/ba/7c7ac20f0d5d97d3d1a35c21916c19f3420457cdb4ea70f714e64277fd1d/ephem-3.7.7.1-cp36-cp36m-manylinux2010_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 49.2MB/s
# Collecting pymeeus<=1,>=0.3.6
#   Downloading https://files.pythonhosted.org/packages/2c/30/47957d487fff94083bdd17247734c165f12b5ac39a3abd1aa476a93eea6e/PyMeeus-0.3.7.tar.gz (732kB)
#      |████████████████████████████████| 737kB 49.5MB/s
# Collecting korean_lunar_calendar
#   Downloading https://files.pythonhosted.org/packages/15/41/aa426a4a9141afd8e7f5c8312bb59d5693274f3f7b34e73bdce4ee48b4c1/korean_lunar_calendar-0.2.1-py3-none-any.whl
# Collecting MarkupSafe>=0.23
#   Downloading https://files.pythonhosted.org/packages/b2/5f/23e0023be6bb885d00ffbefad2942bc51a620328ee910f64abe5a8d18dd1/MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 51.7MB/s
# Collecting cffi>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/1c/1a/90fa7e7ee05d91d0339ef264bd8c008f57292aba4a91ec512a0bbb379d1d/cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401kB)
#      |████████████████████████████████| 409kB 48.9MB/s
# Collecting packaging
#   Downloading https://files.pythonhosted.org/packages/b1/a7/588bfa063e7763247ab6f7e1d994e331b85e0e7d09f853c59a6eb9696974/packaging-20.8-py2.py3-none-any.whl
# Collecting webencodings
#   Downloading https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Collecting async-generator
#   Downloading https://files.pythonhosted.org/packages/71/52/39d20e03abd0ac9159c162ec24b93fbcaa111e8400308f2465432495ca2b/async_generator-1.10-py3-none-any.whl
# Collecting nest-asyncio
#   Downloading https://files.pythonhosted.org/packages/5c/33/10805a3359f56ac4f3b520e64b9d5e6a288d87be95777b8023c64cba60f1/nest_asyncio-1.4.3-py3-none-any.whl
# Collecting pyrsistent>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/4d/70/fd441df751ba8b620e03fd2d2d9ca902103119616f0f6cc42e6405035062/pyrsistent-0.17.3.tar.gz (106kB)
#      |████████████████████████████████| 112kB 59.8MB/s
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/c3/aa/cb45262569fcc047bf070b5de61813724d6726db83259222cd7b4c79821a/attrs-20.3.0-py2.py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 42.6MB/s
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/f3/ed/da40116a204abb5c4dd1d929346d33e0d29cedb2cedd18ea98f0385dcd92/importlib_metadata-3.4.0-py3-none-any.whl
# Collecting pycparser
#   Downloading https://files.pythonhosted.org/packages/ae/e7/d9c3a176ca4b02024debf82342dab36efadfc5776f9c8db077e8f6e71821/pycparser-2.20-py2.py3-none-any.whl (112kB)
#      |████████████████████████████████| 112kB 55.8MB/s
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/41/ad/6a4f1a124b325618a7fb758b885b68ff7b058eec47d9220a12ab38d90b1f/zipp-3.4.0-py3-none-any.whl
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading https://files.pythonhosted.org/packages/60/7a/e881b5abb54db0e6e671ab088d079c57ce54e8a01a3ca443f561ccadb37e/typing_extensions-3.7.4.3-py3-none-any.whl
# Building wheels for collected packages: fbprophet, holidays, pandocfilters, pymeeus, pyrsistent
#   Building wheel for fbprophet (setup.py) ... done
#   Created wheel for fbprophet: filename=fbprophet-0.7.1-cp36-none-any.whl size=6668443 sha256=5ccf1f8aa8db37efbb4c86a6b82b2b8af5e274c22fa89e6bbfb34a48a8d23698
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1otg3tzu/wheels/d3/7d/d1/2985f417ce8c67acadf5f602ff5506bfec2257f32426ad583e
#   Building wheel for holidays (setup.py) ... done
#   Created wheel for holidays: filename=holidays-0.10.4-cp36-none-any.whl size=124776 sha256=c8628d7fe776c38308734d05bfa346c8ee9f54291d1ad9d7622505e57ed0a981
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1otg3tzu/wheels/40/31/ad/edd435075e126fb806bd4dcc6af1c4b5554e53c7562602b51d
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-cp36-none-any.whl size=7992 sha256=0c9ea391820a4d4d498a2959ab478269e368491410528eacdecb1d1c80ec0e53
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1otg3tzu/wheels/93/9a/79/b2c3567908fd6209e4674ca23d9fcf005aae5fe89148913727
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.3.7-cp36-none-any.whl size=702877 sha256=84fdb36b14201b6f71bc87b847bc561b0a037752c8fdaf23015eb21e2002d38f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1otg3tzu/wheels/8d/1a/e7/684cd77a99aac294f976db834fe613b5424f7c4d75ffb0b84d
#   Building wheel for pyrsistent (setup.py) ... done
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp36-cp36m-linux_x86_64.whl size=97026 sha256=f8a63734c6d48a22225069728bd12f8bf7219d0173587154ef438d51dcad5070
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1otg3tzu/wheels/f0/b8/de/b593ad311be4eb458499d100db081e453576032272398b7ddc
# Successfully built fbprophet holidays pandocfilters pymeeus pyrsistent
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.2 which is incompatible.
# ERROR: holidays 0.10.4 has requirement convertdate<=2.2.0, but you'll have convertdate 2.3.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.4.3 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement ipython~=5.5.0, but you'll have ipython 7.16.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement notebook~=5.3.0; python_version >= "3.0", but you'll have notebook 6.1.6 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement tornado~=5.1.0; python_version >= "3.0", but you'll have tornado 6.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, scipy, threadpoolctl, joblib, scikit-learn, xgboost, pickleshare, parso, jedi, setuptools, decorator, pygments, ptyprocess, pexpect, wcwidth, prompt-toolkit, backcall, six, ipython-genutils, traitlets, ipython, pytz, python-dateutil, pandas, patsy, statsmodels, cycler, pillow, pyparsing, kiwisolver, matplotlib, prettytable, seaborn, tornado, pyzmq, jupyter-core, jupyter-client, ipykernel, testpath, packaging, webencodings, bleach, mistune, pyrsistent, attrs, zipp, typing-extensions, importlib-metadata, jsonschema, nbformat, pandocfilters, jupyterlab-pygments, entrypoints, async-generator, nest-asyncio, nbclient, MarkupSafe, jinja2, defusedxml, nbconvert, prometheus-client, Send2Trash, terminado, pycparser, cffi, argon2-cffi, notebook, jupyter-console, jupyterlab-widgets, widgetsnbextension, ipywidgets, qtpy, qtconsole, jupyter, urllib3, Cython, pmdarima, cmdstanpy, pystan, ephem, LunarCalendar, pymeeus, convertdate, korean-lunar-calendar, holidays, setuptools-git, tqdm, fbprophet, auto-ts
# Successfully installed Cython-0.29.17 LunarCalendar-0.0.9 MarkupSafe-1.1.1 Send2Trash-1.5.0 argon2-cffi-20.1.0 async-generator-1.10 attrs-20.3.0 auto-ts-0.0.32 backcall-0.2.0 bleach-3.2.1 cffi-1.14.4 cmdstanpy-0.9.5 convertdate-2.3.0 cycler-0.10.0 decorator-4.4.2 defusedxml-0.6.0 entrypoints-0.3 ephem-3.7.7.1 fbprophet-0.7.1 holidays-0.10.4 importlib-metadata-3.4.0 ipykernel-5.4.3 ipython-7.16.1 ipython-genutils-0.2.0 ipywidgets-7.6.3 jedi-0.18.0 jinja2-2.11.2 joblib-1.0.0 jsonschema-3.2.0 jupyter-1.0.0 jupyter-client-6.1.11 jupyter-console-6.2.0 jupyter-core-4.7.0 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.0 kiwisolver-1.3.1 korean-lunar-calendar-0.2.1 matplotlib-3.3.3 mistune-0.8.4 nbclient-0.5.1 nbconvert-6.0.7 nbformat-5.0.8 nest-asyncio-1.4.3 notebook-6.1.6 numpy-1.19.5 packaging-20.8 pandas-1.1.5 pandocfilters-1.4.3 parso-0.8.1 patsy-0.5.1 pexpect-4.8.0 pickleshare-0.7.5 pillow-8.1.0 pmdarima-1.8.0 prettytable-2.0.0 prometheus-client-0.9.0 prompt-toolkit-3.0.10 ptyprocess-0.7.0 pycparser-2.20 pygments-2.7.4 pymeeus-0.3.7 pyparsing-2.4.7 pyrsistent-0.17.3 pystan-2.19.1.1 python-dateutil-2.8.1 pytz-2020.5 pyzmq-20.0.0 qtconsole-5.0.1 qtpy-1.9.0 scikit-learn-0.24.0 scipy-1.5.4 seaborn-0.11.1 setuptools-51.1.2 setuptools-git-1.2 six-1.15.0 statsmodels-0.12.1 terminado-0.9.2 testpath-0.4.4 threadpoolctl-2.1.0 tornado-6.1 tqdm-4.56.0 traitlets-4.3.3 typing-extensions-3.7.4.3 urllib3-1.26.2 wcwidth-0.2.5 webencodings-0.5.1 widgetsnbextension-3.5.1 xgboost-1.3.1 zipp-3.4.0

# %%
from auto_ts import auto_timeseries
# Out:
# Imported auto_timeseries version:0.0.32. Call by using:
# model = auto_timeseries(score_type='rmse',
#                 time_interval='M',
#                 non_seasonal_pdq=None, seasonality=False, seasonal_period=12,
#                 model_type=['best'],
#                 verbose=2)
# model.fit(traindata, ts_column,target)
# model.predict(testdata, model='best')

# %%
model = auto_timeseries(forecast_period=652,
                        score_type='rmse', time_interval='D',
                        model_type='Prophet')

# %%
train_df.reset_index(inplace=True)

# %%
train_df.head()
# Out:
#         Date  Radiation(KJ/m2)
# 0 2010-01-01            5425.0
# 1 2010-01-02            4761.0
# 2 2010-01-03            5416.0
# 3 2010-01-04            6301.0
# 4 2010-01-05            2318.0

# %%
model.fit(traindata= train_df, 
          ts_column="Date",
          target="Radiation(KJ/m2)")
# Out:
# Start of Fit.....
# Running Augmented Dickey-Fuller test with paramters:
#     maxlag: 2 regression: c autolag: None
# Results of Augmented Dickey-Fuller Test:
# +-----------------------------+------------------------------+
# |                             | Dickey-Fuller Augmented Test |
# +-----------------------------+------------------------------+
# |        Test Statistic       |     -11.252370798812077      |
# |           p-value           |    1.6995521527334953e-20    |
# |          #Lags Used         |             2.0              |
# | Number of Observations Used |            3649.0            |
# |     Critical Value (1%)     |     -3.4321433423211882      |
# |     Critical Value (5%)     |      -2.862332398828442      |
# |     Critical Value (10%)    |      -2.567191805919415      |
# +-----------------------------+------------------------------+
#  this series is stationary
#     Target variable given as = Radiation(KJ/m2)
# Start of loading of data.....
# Input is data frame. Performing Time Series Analysis
# ts_column: Date sep: , target: Radiation(KJ/m2)
#     Dataframe loaded successfully. Shape of data set = (3652, 1)
# Time Interval is given as D
#     Correct Time interval given as a valid Pandas date-range frequency...
#
#
# ==================================================
# Building Prophet Model
# ==================================================
#
#
#
# Running Facebook Prophet Model...
#   Starting Prophet Fit
#       No seasonality assumed since seasonality flag is set to False
#   End of Prophet Fit
#   Starting Prophet Cross Validation
# Max. iterations using expanding window cross validation = 5
#     RMSE = 46,792.92
#     Std Deviation of Originals = 7,186.88
#     Normalized RMSE = 651%
# Cross Validation window: 1 completed
#     RMSE = 4,893.71
#     Std Deviation of Originals = 8,185.94
#     Normalized RMSE = 60%
# Cross Validation window: 2 completed
#     RMSE = 4,333.70
#     Std Deviation of Originals = 7,421.54
#     Normalized RMSE = 58%
# Cross Validation window: 3 completed
#     RMSE = 4,266.01
#     Std Deviation of Originals = 7,208.73
#     Normalized RMSE = 59%
# Cross Validation window: 4 completed
#     RMSE = 5,067.95
#     Std Deviation of Originals = 8,240.57
#     Normalized RMSE = 61%
# Cross Validation window: 5 completed
# Average CV RMSE over 5 windows (macro) = 13070.85522
# Average CV RMSE of all predictions (micro) = 21336.30346
#   End of Prophet Cross Validation
# Time Taken = 21 seconds
# ---------------------------
# Final Prophet CV results:
# ---------------------------
#     RMSE = 21,336.30
#     Std Deviation of Originals = 7,701.89
#     Normalized RMSE = 277%
#
# Best Model is: Prophet
#     Best Model (Mean CV) Score: 13070.86
#
#
# --------------------------------------------------
# Total time taken: 24 seconds.
# --------------------------------------------------
#
#
# Leaderboard with best model on top of list:
#        name          rmse
# 0  Prophet  13070.855225

# %%
future_predictions = model.predict(testdata=652)
# Out:
# Building Forecast dataframe. Forecast Period = 652

# %%
test_df.reset_index(inplace=True)

# %%
test_df["Prophet Predictions"] = future_predictions["yhat"].values

# %%
test_df.head()
# Out:
#         Date  Radiation(KJ/m2)  Prophet Predictions
# 0 2018-03-20            9288.0          2207.782012
# 1 2018-03-21           15722.0          2390.810841
# 2 2018-03-22            7285.0          1995.570298
# 3 2018-03-23            8673.0          2454.624932
# 4 2018-03-24            5310.0          2623.619591

# %%
test_df.set_index("Date", inplace=True)

# %%
test_df.head(3)
# Out:
#             Radiation(KJ/m2)  Prophet Predictions
# Date
# 2018-03-20            9288.0          2207.782012
# 2018-03-21           15722.0          2390.810841
# 2018-03-22            7285.0          1995.570298

# %%
test_df["Radiation(KJ/m2)"].plot(figsize=(15,8), title= 'Radiation', fontsize=14)
test_df["Prophet Predictions"].plot(figsize=(15,8), title= 'Radiation', fontsize=14)
plt.show()
